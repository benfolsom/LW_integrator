# %%
using SymPy, Plots

# %%
@syms x
# Out:
# (x,)

# %%
x = SymPy.symbols("x",real=true,positive=true)
# Out:
# x

# %%
scatter(simplify((1-x^2)/(1-x)^2 + (1-x^2)/(1-x)^3),grid=false,legend=false,m=6)
xlims!(0.94,0.997)
ylims!(-1000,8E4)

# %%
#f_x = ((1-x^2)/(1-x)^2 + (1-x^2)/(1-x)^3)
f_x = (-1)/(1-x)^2 + (1-x^2)/(1-x)^3
g_x = (-1)/(1-x)^2*1/(1+x)^2 + (1-x^2)/(1-x)^3*1/(1+x)^2
#f_x = ((1)/(1-x)^2 + 1/((1-x^2)*(1+x)^2))
# Out:
#                                  2
#           1                 1 - x
# - ───────────────── + ─────────────────
#          2        2          3        2
#   (1 - x) ⋅(x + 1)    (1 - x) ⋅(x + 1)

# %%
simplify(f_x-g_x)
# Out:
#    2
#   x ⋅(x + 2)
# ─────────────
#  4      2
# x  - 2⋅x  + 1

# %%
simplify(f_x)
# Out:
#    x
# ────────
#        2
# (x - 1)

# %%
simplify(g_x)
# Out:
#       x
# ─────────────
#  4      2
# x  - 2⋅x  + 1

# %%
#f_x = ((1-x^2)/(1-x)^2 + (1-x^2)/(1-x)^3)
